# %% [markdown]
# <a href="https://colab.research.google.com/github/RocioLiu/ML_Resources/blob/master/LinAlg_Sec2_Vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ---
# ## Algebraic and geometric interpretations
# ---

# %%
# 2-dimensional vector
v2 = [3, -2]

# 3-dimensional vector
v3 = [4, -3, 2]

# row to column (or vice-versa):
v3t = np.transpose(v3)

# %%
# plot them
plt.plot([0, v2[0]], [0, v2[1]])
plt.axis('equal')
plt.plot([-4,4],[0,0],'k--')
plt.plot([0,0],[-4,4],'k--')
plt.grid()
plt.axis((-4,4,-4,4))
# Out:
# (-4, 4, -4, 4)

# %%
# plot the 3D vector
fig = plt.figure(figsize = plt.figaspect(1))
ax = fig.gca(projection = '3d')
ax.plot([0,v3[0]], [0,v3[1]], [0,v3[2]], linewidth=3)

# make the plot look nicer
ax.plot([0, 0],[0, 0],[-4, 4],'k--')
ax.plot([0, 0],[-4, 4],[0, 0],'k--')
ax.plot([-4, 4],[0, 0],[0, 0],'k--');

# %% [markdown]
# ---
# ## Vector addition / subtraction
# ---

# %%
# two vectors in R2
v1 = np.array([3, -1])
v2 = np.array([2, 4])

v3 = v1 + v2

# %%
# plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')
plt.plot([0, v2[0]]+v1[0],[0, v2[1]]+v1[1],'r',label='v2')
plt.plot([0, v3[0]],[0, v3[1]],'k',label='v1+v2')

plt.legend()
plt.axis('square')
plt.axis((-6, 6, -6, 6 ))
plt.grid()
plt.show()

# %% [markdown]
# ---
# ## Vector-scalar multiplication
# ---

# %%
# vector and scalar
v1 = np.array([3, -1])
l  = -.3
v1m = v1*l # scalar-modulated

# plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v_1')
plt.plot([0, v1m[0]],[0, v1m[1]],'r:',label='\lambda v_1')

plt.axis('square')
plt.axis((-3,3,-3,3))
plt.grid()
plt.show()

# %% [markdown]
# ---
# ## Vector-vector multiplication: the dot product
# ---

# %%
## many ways to compute the dot product
v1 = np.array([1, 2, 3, 4, 5, 6])
v2 = np.array([0, -4, -3, 6, 5, 2])

# %%
# method 1
dp = sum(np.multiply(v1,v2))
dp
# Out:
# 44

# %%
# method 2
dp = np.dot(v1,v2)
dp
# Out:
# 44

# %%
# method 3
dp = np.matmul(v1,v2)
dp
# Out:
# 44

# %%
# method 4
dp = 0  # initialize

# loop over elements
for i in range(0,len(v1)):    
  # multiply corresponding element and sum
  dp = dp + v1[i]*v2[i]
    
print(dp)
# Out:
# 44

# %% [markdown]
# ## Dot product properties: associative and distributive

# %%
## Distributive property

# create random vectors
n = 10
a = np.random.randn(n)
b = np.random.randn(n)
c = np.random.randn(n)

# the two results
res1 = np.dot(a , (b+c))
res2 = np.dot(a,b) + np.dot(a,c)

# compare them
print([res1, res2])
# Out:
# [5.717686888172064, 5.7176868881720635]

# %%
## Associative property

# create random vectors
n = 10
a = np.random.randn(n)
b = np.random.randn(n)
c = np.random.randn(n)

# the two results
res1 = np.dot(a, np.dot(b,c))
res2 = np.dot(np.dot(a,b), c)

# compare them
print(res1)
print(res2)

### special cases where associative property works!
# 1) one vector is the zeros vector
# 2) a==b==c
# Out:
# [-0.15878594 -0.00737991  0.43963452 -0.83718907  0.31198563  0.49331519
#   0.54314407  0.20102148 -0.02757113  0.20882202]
# [ 2.09385019 -0.93098053 -0.89491771  2.4858877   3.30218916 -0.24882502
#  -4.38997721  1.5098718   1.5190775   2.04288677]

# %%
## Dot product with matrix columns between corresponding columns

# create 2 4X6 matrices of random numbers
# Use a for loop to compute dot product
A = np.random.randn(4,6)
B = np.random.randn(4,6)

# %%
A
# Out:
# array([[ 0.61506613, -1.98475122,  0.86732606, -0.39295677,  1.17076319,
#          1.31703634],
#        [ 0.23486084, -0.06302695,  0.18095458, -0.53922752, -0.2225501 ,
#          0.06845212],
#        [-0.1373798 ,  0.26059903, -2.10243292,  0.9937332 , -0.47028278,
#         -1.99418509],
#        [ 0.68127504,  0.51204904,  0.95678892, -0.54714179,  1.7764483 ,
#          0.10053129]])

# %% [markdown]
# ---
# ## Vector length
# ---

# %%
# a vector
v1 = np.array([1, 2, 3, 4, 5, 6])

# methods 1-4, just like with the regular dot product, e.g.:
vl = np.sqrt(sum(np.multiply(v1,v1)))

# method 5: take the norm
vlx = np.linalg.norm(v1)

print(vl, vlx)
# Out:
# 9.539392014169456 9.539392014169456

# %% [markdown]
# ---
# ## The dot product from a geometric perspective
# ---

# %%
# two vectors
v1 = np.array([2, 4, -3])
v2 = np.array([0, -3, -3])

# compute the angle (radians) between two vectors
ang = np.arccos(np.dot(v1,v2) / (np.linalg.norm(v1)*np.linalg.norm(v2)))


# draw them
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot([0, v1[0]],[0, v1[1]],[0, v1[2]],'b')
ax.plot([0, v2[0]],[0, v2[1]],[0, v2[2]],'r')

plt.axis((-6, 6, -6, 6))
plt.title('Angle between vectors: %s rad.' %ang)
plt.show()

# %%
## equivalence of algebraic and geometric dot product formulas

# two vectors
v1 = np.array([2, 4, -3])
v2 = np.array([0, -3, -3])

# algebraic
dp_a = np.dot(v1,v2)

# geometric
dp_g = np.linalg.norm(v1)*np.linalg.norm(v2)*np.cos(ang)

# print dot product to command
print(dp_a)
print(dp_g)
# Out:
# -3
# -3.0000000000000013

# %% [markdown]
# ### Code Challenge
# Test whether the dot product sign is invariant to scaler multiplication

# %%
# Generate two vectors (R3)
v1 = np.array([-3, 4, 6])
v2 = np.array([3, 6, -3])

# Generate two scalers
s1 = 2
s2 = 3

# Compute the dot product between the vectors
print('Original: {}'.format(np.dot(v1, v2)))

# Compute the dot product between scaled vectors
print('Scaled: {}'.format(np.dot(s1*v1, s2*v2)))

print('')
s3 = -2
s4 = 3
print('Original: {}'.format(np.dot(v1, v2)))
print('Scaled: {}'.format(np.dot(s3*v1, s4*v2)))
# Out:
# Original: -3
# Scaled: -18
#
# Original: -3
# Scaled: 18

# %% [markdown]
# ### Code Challenge
# Is the dot product commutative?
# a'*b = b'*a

# %%
# 1) Generate two 100-element random row vectors, compute dot product a with b, b with a
a = np.random.randn(100)
b = np.random.randn(100)
ab = np.dot(a, b)
ba = np.dot(b, a)
print(ab,ba)

# 2) Generate two 2-element integer row vectors, repeat
v = np.array([2,4])
w = np.array([3,5])
vw = np.dot(v, w)
wv = np.dot(w, v)
print(vw, wv)
# Out:
# 0.5122931453035816 0.5122931453035816
# 26 26

# %% [markdown]
# ---
# ## Vector Hadamard multiplication
# ---

# %%
# create vectors
w1 = [1, 3, 5]
w2 = [3, 4, 2]

w3 = np.multiply(w1,w2)
print(w3)
# Out:
# [ 3 12 10]

# %% [markdown]
# ---
# ## Vector outer product
# ---

# %%
v1 = np.array([1, 2, 3])
v2 = np.array([-1, 0, 1])

# outer product
np.outer(v1,v2)

# terrible programming, but helps conceptually:
op = np.zeros((len(v1),len(v1)))
for i in range(0,len(v1)):
  for j in range(0,len(v2)):
    op[i,j] = v1[i] * v2[j]

print(op)
# Out:
# [[-1.  0.  1.]
#  [-2.  0.  2.]
#  [-3.  0.  3.]]

# %% [markdown]
# ---
# ## Vector cross product
# ---

# %%
# create vectors
v1  = [-3, 2, 5]
v2  = [4, -3, 0]

# Python's cross-product function
v3a = np.cross(v1,v2)
print(v3a)

# "manual" method
v3b = [[v1[1]*v2[2] - v1[2]*v2[1]],
       [v1[2]*v2[0] - v1[0]*v2[2]],
       [v1[0]*v2[1] - v1[1]*v2[0]]]

fig = plt.figure()
ax = fig.gca(projection='3d')

# draw plane defined by span of v1 and v2
xx, yy = np.meshgrid(np.linspace(-10,10,10),np.linspace(-10,10,10))
z1 = (-v3a[0]*xx - v3a[1]*yy)/v3a[2]
ax.plot_surface(xx,yy,z1)

## plot the two vectors
ax.plot([0, v1[0]],[0, v1[1]],[0, v1[2]],'k')
ax.plot([0, v2[0]],[0, v2[1]],[0, v2[2]],'k')
ax.plot([0, v3a[0]],[0, v3a[1]],[0, v3a[2]],'r')

ax.view_init(azim=150,elev=45)
plt.show()
# Out:
# [15 20  1]

# %% [markdown]
# ---
# ## Hermitian transpose (a.k.a. conjugate transpose)
# ---

# %%
# create a complex number
z = np.complex(3,4)

# magnitude
print(np.linalg.norm(z))

# by transpose?
print(np.transpose(z)*z)

# by Hermitian transpose
print(np.transpose(z.conjugate())*z)

# complex vector
v = np.array([3, 4j, 5+2j, np.complex(2,-5)])
print(v.T)
print(np.transpose(v))
print(np.transpose(v.conjugate()))
# Out:
# 5.0
# (-7+24j)
# (25+0j)
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.-0.j 0.-4.j 5.-2.j 2.+5.j]

# %% [markdown]
# ---
# ## Unit vector
# ---

# %%
# vector
v1 = np.array([-3, 6])

# mu
mu = 1/np.linalg.norm(v1)

v1n = v1*mu

# plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')
h=plt.plot([0, v1n[0]],[0, v1n[1]],'r',label='v1-norm')
plt.setp(h,linewidth=5)

# axis square
plt.axis('square')
plt.axis((-6, 6, -6, 6))
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Code Challenge
# dot products with unit vectors

# %%
# Create two random-integer vectors (R4)
n=4
v1 = (20*np.random.randn(n)).astype(int)
v2 = (20*np.random.randn(n)).astype(int)

# Compute the length of the individual vectors, and magnitude their dot product
v1n = np.linalg.norm(v1)
v2n = np.linalg.norm(v2)
print(np.dot(v1, v2))

# "Normalize" the vectors (creating unit vectors along the same directions as the oiriginal two vectors)
v1u = (v1/v1n)
v2u = (v2/v2n)
v1un = np.linalg.norm(v1u)
v2un = np.linalg.norm(v2u)
print("The unit vector of v1: ", v1u)
print("Its norm is: ", v1un)
print("The unit vector of v2: ", v2u)
print("Its norm is: ", v2un)

# Compute the magnitude of that dot product
print(np.dot(v1u, v2u))
# Out:
# 124
# The unit vector of v1:  [-0.27652045  0.2419554   0.69130113  0.62217102]
# It norm is:  0.9999999999999999
# The unit vector of v2:  [-0.85649154  0.         -0.4544649   0.24471187]
# It norm is:  1.0
# 0.07491796179286095

# %% [markdown]
# ---
# ## Span
# ---

# %%
# set S
S1 = np.array([1, 1, 0])
S2 = np.array([1, 7, 0])

# vectors v and w
v = np.array([1, 2, 0])
w = np.array([3, 2, 1])

# draw vectors
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot([0, S1[0]],[0, S1[1]],[0, S1[2]],'r')
ax.plot([0, S2[0]],[0, S2[1]],[0, S2[2]],'r')

ax.plot([0, v[0]],[0, v[1]],[0, v[2]],'k')
ax.plot([0, w[0]],[0, w[1]],[0, w[2]],'b')

# now draw plane
xx, yy = np.meshgrid(range(30), range(30))
cp = np.cross(S1,S2)
z1 = (-cp[0]*xx - cp[1]*yy)*1./cp[2]
ax.plot_surface(xx,yy,z1);

plt.show()
